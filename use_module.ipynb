# %%
import imp
#imp.reload(childesr_wrapper)
from modules import childesr_wrapper

# %%
#this kinda sucks, not sure how to fix
childesr_wrapper.connect_to_childes()
# Out:
# R[write to console]: Using current database version: '2018.1'.
# R object with classes: ('MySQLConnection',) mapped to:

# %%
childesr_wrapper.clear_connections()
# Out:
# R[write to console]: Cleared 1 connections
# <rpy2.rinterface_lib.sexp.NULLType object at 0x10fc77320> [RTYPES.NILSXP]

# %%
childesr_wrapper.get_tokens(token = "dog%", corpus = ["providence","manchester"], age = [2, 40])
# Out:
# R[write to console]: Using current database version: '2018.1'.
#
# R[write to console]: Getting data from 19 children in 2 corpora...
#             id  gloss stem part_of_speech  speaker_id  utterance_id  \
# 1      7145956    dog  dog              n        3621       1856507
# 2      7145975    dog  dog              n        3621       1856523
# 3      7145996    dog  dog              v        3617       1856538
# 4      7146021    dog  dog              v        3621       1856544
# 5      7146030    dog  dog              n        3621       1856541
# ...        ...    ...  ...            ...         ...           ...
# 3375  40723774   dogs  dog              v       15457      10630689
# 3376  40741490   dogs  dog              n       15457      10635792
# 3377  40881936   dogs  dog              v       15455      10671850
# 3378   8685838  dogs'  dog              n        3672       2242459
# 3379   8734634  dogs'  dog              n        3672       2254349
#
# ...

# %%
childesr_wrapper.get_database_version()
# Out:
# R[write to console]: Using current database version: '2018.1'.
# '2018.1'
